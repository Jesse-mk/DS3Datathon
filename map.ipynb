# %%
# 1. convert addresses to long, lat
# 2. use into gmaps for python
import numpy as np
from collections import defaultdict
import nltk 
import pandas as pd
import os 
import json
import io
import gzip
import random

# %%
import gmaps
# import geocoder
import gmaps.datasets
gmaps.configure(api_key="AIzaSyC4K8XQ-MoiH5mlyxvkVTarCuAyE0pVDR0")
# Geocoder.configure(api_key="AIzaSyC4K8XQ-MoiH5mlyxvkVTarCuAyE0pVDR0")# Your Google API key

# %%
# read in a gz file
def readGz(fname):
    gz = gzip.open(fname, 'rb')
    f = io.BufferedReader(gz)
    data = []
    rows = 0

    for l in f.readlines():
        rows = rows + 1
        data.append(eval(l))
        if rows == 2000:
            break;
        
    gz.close()
    return data
#     for l in gzip.open(f):
#         yield eval(l)

# %%
#have a random sample so it's more representative of the population
random.seed(42)
def random_sampler(filename, k):
    sample = []
    with open(filename, 'rb') as f:
        f.seek(0, 2)
        filesize = f.tell()
        random_set = sorted(random.sample(range(filesize), k))

        for i in range(k):
            f.seek(random_set[i])
            # Skip current line (because we might be in the middle of a line) 
            f.readline()
            # Append the next line to the sample set 
            val = ast.literal_eval(f.readline().rstrip().decode('utf-8'))
            sample.append(val)

    return sample

# %%
places = readGz("places.clean.json.gz")
users = readGz("users.clean.json.gz")
reviews = readGz("reviews.clean.json.gz")

# %%
places = pd.DataFrame(places)
users = pd.DataFrame(users)
reviews = pd.DataFrame(reviews)

# %%
prev_merge = reviews.merge(users, how = 'outer') #, #= "gPlusUserId")

# %%
new = prev_merge.merge(places, how="outer")

# %%
new

# %%
df = new[pd.notnull(new['address'])]

# %%
# df

# %%
df["address"]

# %%
# os.environ["GOOGLE_API_KEY"] = "AIzaSyC4K8XQ-MoiH5mlyxvkVTarCuAyE0pVDR0"

# from geopy.geocoders import Nominatim
# geolocator = Nominatim(user_agent="cindy")
# location = geolocator.geocode("1 Place Carolane, 66760 Latour-de-Carol, France")

# print((location.latitude, location.longitude))

# %%
# geocode("")
# g = geocoder.google('8349 Mira Mesa Blvd, San Diego, CA 92126')

# import geocoder
# g = geocoder.google('8349 Mira Mesa Blvd, San Diego, CA 92126', key="AIzaSyC4K8XQ-MoiH5mlyxvkVTarCuAyE0pVDR0")
# e = geocoder.google("9500 Culver Blvd, Culver City, CA 90232", key="AIzaSyC4K8XQ-MoiH5mlyxvkVTarCuAyE0pVDR0")
# f = geocoder.google('29000 Lilac Rd, Valley Center, CA 92082', key="AIzaSyC4K8XQ-MoiH5mlyxvkVTarCuAyE0pVDR0")

# %%
yes = pd.read_csv("translated_final_df.csv")

loc_col = yes["gps"]

name_col = yes["name"]

star_col = yes["rating"]

# %%
# marker_locations = [
#     g.latlng,
#     e.latlng,
#     f.latlng
# ]

# fig = gmaps.figure()
# markers = gmaps.marker_layer(marker_locations)
# fig.add_layer(markers)
# fig

# %%
yes[yes['gps'].str.len() < 8]['gps']
yes = yes[yes['gps'] != 'None']
# yes[yes['gps'].str.len() > 9]['gps']

# %%
yes2 = yes[['name', 'gps', 'rating']]
yes2
# Out:
# 9032                تويوتا منيف النهدي فرع 10    (18.398503, 42.705949)
# 9033                    Medvedkovo, Dom Knigi    (55.884908, 37.657237)
# 9034                       Taleghani Hospital    (38.072983, 46.232411)
# 9035                     Victorinox Genève SA     (46.203349, 6.145632)
# 9036                        Salon De Coiffure    (55.666021, 12.396972)
# 9037                                 Room 157     (43.568511, 1.480883)
# 9038                                      覺善堂   (22.616839, 120.522356)
# 9039                           Sapori del sud     (50.657627, 4.626812)
# 9040  Center Parcs Moselle - Les Trois Forêts     (48.626611, 7.000577)
#
#       rating
# 0        5.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        5.0
# 5        2.0
# 6        5.0
# 7        1.0
# 8        5.0
# 9        2.0
# 10       3.0
# 11       5.0
# 12       4.0
# 13       4.0
# 14       5.0
# 15       5.0
# 16       4.0
# 17       5.0
# 18       4.0
# 19       5.0
# 20       5.0
# 21       2.0
# 22       5.0
# 23       5.0
# 24       5.0
# 25       5.0
# 26       5.0
# 27       4.0
# 28       5.0
# 29       5.0
# ...      ...
# 9011     5.0
# 9012     5.0
# 9013     4.0
# 9014     5.0
# 9015     4.0
# 9016     2.0
# 9017     5.0
# 9018     5.0
# 9019     3.0
# 9020     2.0
# 9021     5.0
# 9022     4.0
# 9023     5.0
# 9024     4.0
# 9025     5.0
# 9026     5.0
# 9027     4.0
# 9028     5.0
# 9029     5.0
# 9030     5.0
# 9031     5.0
# 9032     5.0
# 9033     4.0
# 9034     4.0
# 9035     5.0
# 9036     5.0
# 9037     1.0
# 9038     5.0
# 9039     4.0
# 9040     5.0
#
# [9020 rows x 3 columns]

# %%
l = []
for i, row in yes2.iterrows():
    lat_long = row['gps'][1:-1]
    #print(lat_long)
    if (float(lat_long[0:lat_long.index(',')]) >= -90 and float(lat_long[0:lat_long.index(',')]) < 90):
        lat = float(lat_long[0:lat_long.index(',')])
        lng = float(lat_long[lat_long.index(' ') + 1:])
        l.append({'name': row['name'], 'gps': (lat,lng), 'rating': row['rating']})
    else:
        pass
len(l)
# Out:
# 8966

# %%
# rest_info = [
#     {'name': 'Atucha', 'location': (-34.0, -59.167), 'active_reactors': 1},
#     {'name': 'Embalse', 'location': (-32.2333, -64.4333), 'active_reactors': 1},
#     {'name': 'Armenia', 'location': (40.167, 44.133), 'active_reactors': 1},
#     {'name': 'Br', 'location': (51.217, 5.083), 'active_reactors': 1},
#     {'name': 'Doel', 'location': (51.333, 4.25), 'active_reactors': 4},
#     {'name': 'Tihange', 'location': (50.517, 5.283), 'active_reactors': 3}
# ]


place_locations = [place['gps'] for place in l] #list of lat/lng
#place_locations = [yes2["gps"]]
#print(place_locations) 

info_box_template = """
<dl>
<dt>Name</dt><dd>{name}</dd>
<dt>Star Rating</dt><dd>{rating}</dd>
</dl>
"""

#for every line in the dict, it is gonna apply the info box template
place_info = [info_box_template.format(**place) for place in l]

marker_layer = gmaps.marker_layer(place_locations, info_box_content=place_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)
fig
# address
# Out:
# Figure(layout=FigureLayout(height='420px'))
